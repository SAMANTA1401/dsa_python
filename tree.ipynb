# %% [markdown]
# ![image.png](attachment:image.png)

# %%
class TreeNode:
    def __init__(self, data):
        self.data = data
        self.children = []
        self.parent = None

    def add_child(self, child):
        child.parent = self # current instance of class
        self.children.append(child)
    
    def get_level(self):
        level = 0
        p = self.parent # last child
        while p:
            level += 1
            p = p.parent
        return level

    def print_tree(self):
        print(" "* self.get_level()*4 + "|--" +self.data)
        # print(" "* len(self.children)*4 + "|--" +self.data)

        for child in self.children:
            # print(child.data)
            child.print_tree()

# %%
def build_product_tree():
    root = TreeNode("electronics")

    laptop = TreeNode("laptop")
    laptop.add_child(TreeNode("Mac"))
    laptop.add_child(TreeNode("Surface"))
    laptop.add_child(TreeNode("Thinkpad"))

    cellphone = TreeNode("Cell Phone")
    cellphone.add_child(TreeNode("iPhone"))
    cellphone.add_child(TreeNode("Google Pixel"))
    cellphone.add_child(TreeNode("Vivo"))

    tv = TreeNode("TV")
    tv.add_child(TreeNode("Samsung"))
    tv.add_child(TreeNode("LG"))

    root.add_child(laptop)
    root.add_child(cellphone)
    root.add_child(tv)

    # root.print_tree()
    return root

# %%
root = build_product_tree()

# %%
root.print_tree()
# Out:
# |--electronics
#     |--laptop
#         |--Mac
#         |--Surface
#         |--Thinkpad
#     |--Cell Phone
#         |--iPhone
#         |--Google Pixel
#         |--Vivo
#     |--TV
#         |--Samsung
#         |--LG

# %%
print(root.parent)
# Out:
# None

# %%
print(root.data)
# Out:
# electronics

# %%
print(len(root.children))
# Out:
# 3

# %%
for child in root.children:
    print(child.data)
    print(child.parent.data)
    print("***")
# Out:
# laptop
# electronics
# ***
# Cell Phone
# electronics
# ***
# TV
# electronics
# ***

# %%
print(child.children)
# Out:
# [<__main__.TreeNode object at 0x00000267968045D0>, <__main__.TreeNode object at 0x0000026796804310>]

# %%
for child in root.children:
    print(child.data)
    print("//////")
    for grandchild in child.children:
        print(grandchild.data)
        print(grandchild.parent.data)
        print("***")
# Out:
# laptop
# //////
# Mac
# laptop
# ***
# Surface
# laptop
# ***
# Thinkpad
# laptop
# ***
# Cell Phone
# //////
# iPhone
# Cell Phone
# ***
# Google Pixel
# Cell Phone
# ***
# Vivo
# Cell Phone
# ***
# TV
# //////
# Samsung
# TV
# ***
# LG
# TV
# ***
