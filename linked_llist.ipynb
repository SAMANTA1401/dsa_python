# %% [markdown]
# ![Screenshot_20230412-175521.jpg](attachment:Screenshot_20230412-175521.jpg)

# %% [markdown]
# ![Screenshot_20230412-180040.jpg](attachment:Screenshot_20230412-180040.jpg)

# %% [markdown]
# ![Screenshot_20230412-233538.jpg](attachment:Screenshot_20230412-233538.jpg)

# %% [markdown]
# ![Screenshot_20230413-112117.jpg](attachment:Screenshot_20230413-112117.jpg)

# %% [markdown]
# ![Screenshot_20230417-140627.jpg](attachment:Screenshot_20230417-140627.jpg)

# %%
class Node:
    def __init__(self, value):
        self.data = value
        self.next = None

# %%
class LinkedList:
    def __init__(self):
        #Empty Linked List
        self.head = None # this represent the first node that is empty data + next
        #no of nodes in the LL
        self.n = 0

    def __len__(self):
        return self.n

    
    def insert_head(self, value):
        # new node
        new_node = Node(value)
        #create connection
        new_node.next = self.head # set None to next
        #reassign head
        self.head = new_node # set node to head
        # increment n
        self.n = self.n + 1
    
    def traverse(self):
        curr = self.head # curr is full node data + next
        if curr == None:
            print(" Error: Empty Linked List")
        while curr != None:
            print(curr.data)
            curr = curr.next

    def reverse(self):
        prev_node = None
        curr_node = self.head
        while curr_node != None:
            next_node = curr_node.next
            curr_node.next = prev_node
            prev_node = curr_node
            curr_node = next_node
        self.head = prev_node

    def append(self,value):
        new_node = Node(value)
        if self.head == None:
            #empty
            self.head = new_node
            self.n = self.n + 1
            return

        curr = self.head
        while curr.next != None:
            curr = curr.next
        #you are at the last node
        curr.next = new_node

    def insert_after(self,after, value):
        new_node = Node(value)
        curr = self.head
        if self.head == None:
            return "Empty Linked List"
        while curr != None:
            if curr.data == after:
                break
            curr = curr.next

        #case 1 break -> item is found then curr not none
        if curr != None:
            #logic
            new_node.next = curr.next
            curr.next = new_node
        else:
            print("Item not found")

        print(curr.data)

    def search(self,item):
        curr = self.head
        pos = 0
        while curr != None:
            if curr.data == item:
                return pos
            curr = curr.next
            pos = pos + 1
        return "Item Not Found"
    
    def __getitem__(self,index):
        curr = self.head
        pos = 0
        while curr != None:
            if pos == index:
                return curr.data
            curr = curr.next
            pos = pos + 1
        return "IndexError"
    

    # 7->6->5
    def clear(self):
        self.head = None
        self.n = 0


    def delete_head(self):
        if self.head == None:
            return "Empty Linked List"
        self.head = self.head.next

    def pop(self):
        curr = self.head
        if curr == None:
            return "Empty Linked List"
        if curr.next == None:
            #delete head
            return self.delete_head()
        while curr.next.next != None:
            curr = curr.next
        #curr -> 2nd last node
        curr.next = None
        self.n = self.n - 1

    def remove(self,value):
        if self.head.data == value:
            return self.delete_head()
        curr = self.head
        while curr.next != None:
            if curr.next.data == value:
                break
            curr = curr.next
        # if item is not found
        if curr.next == None:
            return "Item not found"
        else:
            curr.next = curr.next.next
            self.n = self.n - 1

    def replace_max(self, value):  
        temp = self.head
        maxe = temp
        while temp != None:
            if temp.data > maxe.data:
                maxe = temp
            temp = temp.next
        maxe.data = value


    def __str__(self):
        curr = self.head
        result = ""
        if curr == None:
            print("Empty linked list")
        while curr != None:
            result = result + str(curr.data) + "->"
            curr = curr.next
        return result[:-2]

# %%
L = LinkedList()

# %%
L.insert_head(5)
L.insert_head(6)
L.insert_head(7)

# %%
L.head #7

# %%
L.head.next #6

# %%
L.head.next.next #5

# %%
L.head.next.next.next

# %%
print(L)
# Out:
# 7->6->5

# %%
L.traverse()
# Out:
# 7
# 6
# 5

# %%
L.reverse()

# %%
L.traverse()
# Out:
# 5
# 6
# 7

# %%
L.head #5

# %%
L.head.next

# %%
L.head.next.next
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 L.head.next.next
#
# AttributeError: 'NoneType' object has no attribute 'next'

# %%
L.replace_max(10)

# %%
print(L)
# Out:
# 10->6->5

# %%
L[12]
# Out:
# 'IndexError'

# %%
L.search(6)
# Out:
# 1

# %%
L.remove(6)

# %%
print(L)
# Out:
# 7->5

# %%
L.pop()

# %%
L.delete_head()

# %%
L.insert_after(6,200)
# Out:
# 'Empty Linked List'

# %%
L.clear()

# %%
print(L)
# Out:
# Empty linked list

# %%
L.append(45)

# %%
print(L)
# Out:
# 45

# %%
len(L)
# Out:
# 1

# %%
L.traverse()
# Out:
# 45

# %% [markdown]
# 1. what is the output of following function when head node of following linked list is passed as input?  1->2->3->4->5

# %%
L.insert_head(5)
L.insert_head(4)
L.insert_head(3)
L.insert_head(2)
L.insert_head(1)

# %%
head = L.head

# %%
print(head)
# Out:
# <__main__.Node object at 0x00000246EDADDD10>

# %%
head.data
# Out:
# 1

# %%
head.next

# %%
head.next.data
# Out:
# 2

# %%
head.next.next

# %%
head.next.next.data
# Out:
# 3

# %%
id(3)
# Out:
# 140713496314728

# %%
def fun(head):
    if head is None:
        return 0
    if head.next.next != None:
        print(head.data,"",end="")
        fun(head.next)
    print(head.data,"",end='')

# %%
fun(head)
# Out:
# 1 2 3 4 5 4 3 2 1

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# def fun(head): 1
#     if head is None:
#         return 0
#     if head.next.next != None:
#         print(head.data,"",end="") 1
#         fun(head.next)  ---->def fun(head): 2
#                                 if head is None:
#                                     return 0
#                                 if head.next.next != None:
#                                     print(head.data,"",end="") 2
#                                     fun(head.next)  ---->  def fun(head): 3
#                                                                 if head is None:
#                                                                     return 0
#                                                                 if head.next.next != None:
#                                                                     print(head.data,"",end="") 3
#                                                                     fun(head.next)  ----> def fun(head): 4
#                                                                                                 if head is None:
    #                                                                                                 return 0
    #                                                                                             if head.next.next != None:
    #                                                                                                 print(head.data,"",end="") 4
    #                                                                                                 fun(head.next)  ----> def fun(head): 5
    #                                                                                                                             if head is None:
    #                                                                                                                                 return 0
    #                                                                                                                             if head.next.next != None: # not satisfied
    #                                                                                                                                 print(head.data,"",end="") 
    #                                                                                                                                 fun(head.next)  ---->

    #                                                                                                                             print(head.data,"",end='') 5


    #                                                                                             print(head.data,"",end='') 4

    #                                                             print(head.data,"",end='') 3

    #                             print(head.data,"",end='') 2

    # print(head.data,"",end='') 1

# %% [markdown]
# 1 > Write a python program t ofind the maximum value in a linked list and replace it with a given value, Assume that the linked lsit is populated with whole numbers and there is only one maximum value in the linked list

# %%
L.replace_max(10)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 L.replace_max(10)
#
# Cell In[16], line 127, in LinkedList.replace_max(self, value)
#     125 temp = self.head
#     126 max = temp
# --> 127 while temp != None:
#     128     if temp.data > max.data:
#     129         max = temp
#
# KeyboardInterrupt:

# %%
head = L.head

# %%
print(head.data)
# Out:
# 7

# %%
def replace_maxo(value):  
        temp = head
        max = temp
        while temp != None:
            if temp.data > max.data:
                max = temp
            temp = temp.next
        max.data = value

# %%
L.insert_head(3)
L.insert_head(2)
L.insert_head(5)
L.insert_head(7)

# %%
print(L)
# Out:
# 7->5->2->3->3->15->6->5

# %%
replace_maxo(15)

# %%
print(L)
# Out:
# 7->5->2->3->3->15->6->5

# %%
L.traverse()
# Out:
# 7
# 5
# 2
# 3
# 3
# 15
# 6
# 5

# %%
head.data
# Out:
# 7

# %%
def sum_odd_nodes(head):
    temp = head
    # print(temp.data)
    counter = 1
    result = 0
    while temp != None:
        if counter%2 != 0:
            result = result + temp.data
            print(temp.data)
        counter += 1
        temp = temp.next
        # print(temp)
    print(result)

# %%
sum_odd_nodes(head)
# Out:
# 7
# 2
# 3
# 6
# 18

# %% [markdown]
# 3. Write a python code to reverse a linked list containing interger data

# %%
ll = LinkedList()

# %%
ll.insert_head(1)
ll.insert_head(2)
ll.insert_head(3)
ll.insert_head(4)

# %%
print(ll)
# Out:
# 4->3->2->1

# %%
head = ll.head

# %%
print(head.data)
# Out:
# 4

# %%
head.next

# %%
head.next.data
# Out:
# 3

# %% [markdown]
# 4->3->2->1->1

# %%
head.data
# Out:
# 4

# %%
ll.traverse()
# Out:
# 4

# %%
print(ll)
# Out:
# 4

# %%
head = ll.head

# %%
print(ll.head.data)
# Out:
# 4

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def change_sent(self):
    temp = self.head
    while temp != None:
        if temp.data == '*' or temp.data == '/':
            temp.data = ' '
            if temp.next.data == '*' or temp.next.data=='/':
                temp.next.next.data = temp.next.next.data.upper()
                temp.next = temp.next.next
        temp = temp.next
