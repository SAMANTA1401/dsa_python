# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def merge_sort(arr):
    if  len(arr) <= 1:
        return arr
    
    mid = len(arr) // 2

    left = arr[:mid]
    right = arr[mid:]

    left = merge_sort(left)
    right = merge_sort(right)

    merge_two_sorted_lists(left,right,arr)

# %%
def merge_two_sorted_lists(a,b,arr):

    # sorted_lists = []

    len_a = len(a)
    len_b = len(b)

    i = j = k= 0

    while i < len_a and j < len_b:
        if a[i] <= b[j]:
            arr[k] = a[i]
            # sorted_lists.append(a[i])
            i +=1
        else:
            arr[k] = b[j]
            # sorted_lists.append(b[j])
            j +=1
        
        k+=1

    while i < len_a:
        arr[k] = a[i]
        # sorted_lists.append(a[i])
        i +=1
        k += 1
    while j < len_b:
        arr[k] = b[j]
        # sorted_lists.append(b[j])
        j +=1 
        k += 1


    # return sorted_lists

# %%
a = [5,8,12,56]
b = [7,9,45,51]
arr = [5,8,12,56,7,9,45,51]

# %%
merge_sort(arr)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 merge_sort(arr)
#
# Cell In[44], line 10, in merge_sort(arr)
#       7 left = arr[:mid]
#       8 right = arr[mid:]
# ---> 10 left = merge_sort(left)
#      11 right = merge_sort(right)
#      13 merge_two_sorted_lists(left,right,arr)
#
# Cell In[44], line 13, in merge_sort(arr)
#      10 left = merge_sort(left)
#      11 right = merge_sort(right)
# ---> 13 merge_two_sorted_lists(left,right,arr)
#
# Cell In[45], line 5, in merge_two_sorted_lists(a, b, arr)
#       1 def merge_two_sorted_lists(a,b,arr):
#       2
#       3     # sorted_lists = []
# ----> 5     len_a = len(a)
#       6     len_b = len(b)
#       8     i = j = k= 0
#
# TypeError: object of type 'NoneType' has no len()

# %%
print(merge_two_sorted_lists(a,b))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 print(merge_two_sorted_lists(a,b))
#
# TypeError: merge_two_sorted_lists() missing 1 required positional argument: 'arr'

# %%
def merge_sort(arr):
    if len(arr) <= 1:
        return

    mid = len(arr)//2

    left = arr[:mid]
    right = arr[mid:]

    merge_sort(left)
    merge_sort(right)

    merge_two_sorted_lists(left, right, arr)

def merge_two_sorted_lists(a,b,arr):
    len_a = len(a)
    len_b = len(b)

    i = j = k = 0

    while i < len_a and j < len_b:
        if a[i] <= b[j]:
            arr[k] = a[i]
            i+=1
        else:
            arr[k] = b[j]
            j+=1
        k+=1

    while i < len_a:
        arr[k] = a[i]
        i+=1
        k+=1

    while j < len_b:
        arr[k] = b[j]
        j+=1
        k+=1

if __name__ == '__main__':
    test_cases = [
        [10, 3, 15, 7, 8, 23, 98, 29],
        [],
        [3],
        [9,8,7,2],
        [1,2,3,4,5]
    ]

    for arr in test_cases:
        merge_sort(arr)
        print(arr)
# Out:
# [3, 7, 8, 10, 15, 23, 29, 98]
# []
# [3]
# [2, 7, 8, 9]
# [1, 2, 3, 4, 5]
