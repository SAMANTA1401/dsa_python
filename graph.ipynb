# %% [markdown]
# ![image.png](attachment:image.png)

# %%
class Graph:
    def __init__(self,edges):
        self.edges = edges #convert tuple to dictionary
        self.graph_dict = {}
        for start, end in self.edges:
            if start in self.graph_dict:
                self.graph_dict[start].append(end)
            else:
                self.graph_dict[start] = [end]
        print("Graph dict:",self.graph_dict)

    def get_paths(self, start, end, path=[]):
        path = path + [start]

        if start == end:
            return [path]
        if start not in self.graph_dict:
            return []
    
        paths = []

        for node in self.graph_dict[start]:
            if node not in path:
                new_paths = self.get_paths(node, end, path)
                for p in new_paths:
                    paths.append(p)

        return paths
    
    def get_shortest_path(self, start, end, path=[]):
        path = path + [start]

        if start == end:
            return path
        
        if start not in self.graph_dict:
            return None
        
        shortest_path = None
        for node in self.graph_dict[start]:
            if node not in path:
                sp = self.get_shortest_path(node, end, path)
                if sp:
                    if shortest_path is None or len(sp) < len(shortest_path):
                        shortest_path = sp

        return shortest_path

# %%
routes = [("mumbai","paris"),
         ("paris","tokyo"),
         ("tokyo","mumbai"),
         ("mumbai","delhi"),
         ("delhi","tokyo"),
         ("delhi","mumbai"),
         ("tokyo","delhi"),
         ("paris","delhi"),
         ("mumbai","tokyo")]

# %%
route_graph = Graph(routes)
# Out:
# Graph dict: {'mumbai': ['paris', 'delhi', 'tokyo'], 'paris': ['tokyo', 'delhi'], 'tokyo': ['mumbai', 'delhi'], 'delhi': ['tokyo', 'mumbai']}

# %%
start = "mumbai"
end = "delhi"
print(f"paths between {start} and {end}: ", route_graph.get_paths(start, end))
# Out:
# paths between mumbai and delhi:  [['mumbai', 'paris', 'tokyo', 'delhi'], ['mumbai', 'paris', 'delhi'], ['mumbai', 'delhi'], ['mumbai', 'tokyo', 'delhi']]

# %%
start = "mumbai"
end = "delhi"
print(f"shortest paths between {start} and {end}: ", route_graph.get_shortest_path(start, end))
# Out:
# shortest paths between mumbai and delhi:  ['mumbai', 'delhi']

# %%
d = {
    "mumbai":["paris", "dubai"],
    "paris": ["dubai","new york"]
}

# %%
# 11:19
